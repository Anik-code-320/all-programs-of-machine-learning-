# %%
import pandas as pd 
df1=pd.read_csv("dataset.csv")
df1
# Out:
#          AT      V       AP     RH      PE
# 0      8.34  40.77  1010.84  90.01  480.48
# 1     23.64  58.49  1011.40  74.20  445.75
# 2     29.74  56.90  1007.15  41.91  438.76
# 3     19.07  49.69  1007.22  76.79  453.09
# 4     11.80  40.66  1017.13  97.20  464.43
# ...     ...    ...      ...    ...     ...
# 9563  15.12  48.92  1011.80  72.93  462.59
# 9564  33.41  77.95  1010.30  59.72  432.90
# 9565  15.99  43.34  1014.20  78.66  465.96
# 9566  17.65  59.87  1018.58  94.65  450.93
# 9567  23.68  51.30  1011.86  71.24  451.67
#
# [9568 rows x 5 columns]

# %%
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %%
df.tail()
# Out:
#          AT      V       AP     RH      PE
# 9563  15.12  48.92  1011.80  72.93  462.59
# 9564  33.41  77.95  1010.30  59.72  432.90
# 9565  15.99  43.34  1014.20  78.66  465.96
# 9566  17.65  59.87  1018.58  94.65  450.93
# 9567  23.68  51.30  1011.86  71.24  451.67

# %%
from sklearn.impute import SimpleImputer 
imp=SimpleImputer(strategy='mean')

# %%
imp.fit(df)
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='mean', verbose=0)

# %%
df1=imp.transform(df)
df1
# Out:
# array([[   8.34,   40.77, 1010.84,   90.01,  480.48],
#        [  23.64,   58.49, 1011.4 ,   74.2 ,  445.75],
#        [  29.74,   56.9 , 1007.15,   41.91,  438.76],
#        ...,
#        [  15.99,   43.34, 1014.2 ,   78.66,  465.96],
#        [  17.65,   59.87, 1018.58,   94.65,  450.93],
#        [  23.68,   51.3 , 1011.86,   71.24,  451.67]])

# %%
imp2=SimpleImputer(strategy='median')
imp2.fit(df)

imp2.transform(df)
imp2
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='median', verbose=0)

# %%
imp3=SimpleImputer(strategy='most_frequent')
imp3.fit(df)
imp3
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='most_frequent', verbose=0)

# %%
pd.DataFrame(df)
# Out:
#          AT      V       AP     RH      PE
# 0      8.34  40.77  1010.84  90.01  480.48
# 1     23.64  58.49  1011.40  74.20  445.75
# 2     29.74  56.90  1007.15  41.91  438.76
# 3     19.07  49.69  1007.22  76.79  453.09
# 4     11.80  40.66  1017.13  97.20  464.43
# ...     ...    ...      ...    ...     ...
# 9563  15.12  48.92  1011.80  72.93  462.59
# 9564  33.41  77.95  1010.30  59.72  432.90
# 9565  15.99  43.34  1014.20  78.66  465.96
# 9566  17.65  59.87  1018.58  94.65  450.93
# 9567  23.68  51.30  1011.86  71.24  451.67
#
# [9568 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv('adult.csv')
df
# Out:
#        39          State-gov   77516    Bachelors  Unnamed: 4  \
# 0      50   Self-emp-not-inc   83311    Bachelors          13
# 1      38            Private  215646      HS-grad           9
# 2      53            Private  234721         11th           7
# 3      28            Private  338409    Bachelors          13
# 4      37            Private  284582      Masters          14
# ...    ..                ...     ...          ...         ...
# 32555  27            Private  257302   Assoc-acdm          12
# 32556  40            Private  154374      HS-grad           9
# 32557  58            Private  151910      HS-grad           9
# 32558  22            Private  201490      HS-grad           9
# 32559  52       Self-emp-inc  287927      HS-grad           9
#
#              Never-married        Adm-clerical   Not-in-family   White  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#           Male     2174  0    40   United-States   <=50K
# 0         Male      0.0  0  13.0   United-States   <=50K
# 1         Male      0.0  0  40.0   United-States   <=50K
# 2         Male      0.0  0   NaN   United-States   <=50K
# 3       Female      0.0  0  40.0            Cuba   <=50K
# 4       Female      0.0  0  40.0   United-States   <=50K
# ...        ...      ... ..   ...             ...     ...
# 32555   Female      0.0  0  38.0   United-States   <=50K
# 32556     Male      0.0  0  40.0   United-States    >50K
# 32557   Female      0.0  0  40.0   United-States   <=50K
# 32558     Male      0.0  0  20.0   United-States   <=50K
# 32559   Female  15024.0  0  40.0   United-States    >50K
#
# [32560 rows x 15 columns]

# %%
df.isnull().sum().sum()
# Out:
# 2

# %%
df.head(10)
# Out:
#    39          State-gov   77516      Bachelors  Unnamed: 4  \
# 0  50   Self-emp-not-inc   83311      Bachelors          13
# 1  38            Private  215646        HS-grad           9
# 2  53            Private  234721           11th           7
# 3  28            Private  338409      Bachelors          13
# 4  37            Private  284582        Masters          14
# 5  49            Private  160187            9th           5
# 6  52   Self-emp-not-inc  209642        HS-grad           9
# 7  31            Private   45781        Masters          14
# 8  42            Private  159449      Bachelors          13
# 9  37            Private  280464   Some-college          10
#
#             Never-married        Adm-clerical   Not-in-family   White  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# 2      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3      Married-civ-spouse      Prof-specialty            Wife   Black
# 4      Married-civ-spouse     Exec-managerial            Wife   White
# 5   Married-spouse-absent       Other-service   Not-in-family   Black
# 6      Married-civ-spouse     Exec-managerial         Husband   White
# 7           Never-married      Prof-specialty   Not-in-family   White
# 8      Married-civ-spouse     Exec-managerial         Husband   White
# 9      Married-civ-spouse     Exec-managerial         Husband   Black
#
#       Male    2174  0    40   United-States   <=50K
# 0     Male     0.0  0  13.0   United-States   <=50K
# 1     Male     0.0  0  40.0   United-States   <=50K
# 2     Male     0.0  0   NaN   United-States   <=50K
# 3   Female     0.0  0  40.0            Cuba   <=50K
# 4   Female     0.0  0  40.0   United-States   <=50K
# 5   Female     0.0  0  16.0         Jamaica   <=50K
# 6     Male     0.0  0  45.0   United-States    >50K
# 7   Female     NaN  0  50.0   United-States    >50K
# 8     Male  5178.0  0  40.0   United-States    >50K
# 9     Male     0.0  0  80.0   United-States    >50K

# %%
df.tail(5)
# Out:
#        39      State-gov   77516    Bachelors  Unnamed: 4  \
# 32555  27        Private  257302   Assoc-acdm          12
# 32556  40        Private  154374      HS-grad           9
# 32557  58        Private  151910      HS-grad           9
# 32558  22        Private  201490      HS-grad           9
# 32559  52   Self-emp-inc  287927      HS-grad           9
#
#              Never-married        Adm-clerical  Not-in-family   White  \
# 32555   Married-civ-spouse        Tech-support           Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct        Husband   White
# 32557              Widowed        Adm-clerical      Unmarried   White
# 32558        Never-married        Adm-clerical      Own-child   White
# 32559   Married-civ-spouse     Exec-managerial           Wife   White
#
#           Male     2174  0    40   United-States   <=50K
# 32555   Female      0.0  0  38.0   United-States   <=50K
# 32556     Male      0.0  0  40.0   United-States    >50K
# 32557   Female      0.0  0  40.0   United-States   <=50K
# 32558     Male      0.0  0  20.0   United-States   <=50K
# 32559   Female  15024.0  0  40.0   United-States    >50K
